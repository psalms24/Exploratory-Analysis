# %% [markdown]
# ### ANALYSIS OF HOUSE PRICE IN USA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("house.csv")

# %%
data.head()
# Out:
#               date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  02/05/2014 0:00   313000.0         3       1.50         1340      7912
# 1  02/05/2014 0:00  2384000.0         5       2.50         3650      9050
# 2  02/05/2014 0:00   342000.0         3       2.00         1930     11947
# 3  02/05/2014 0:00   420000.0         3       2.25         2000      8030
# 4  02/05/2014 0:00   550000.0         4       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
data.tail()
# Out:
#                  date        price  bedrooms  bathrooms  sqft_living  \
# 4595  09/07/2014 0:00  308166.6667         3       1.75         1510
# 4596  09/07/2014 0:00  534333.3333         3       2.50         1460
# 4597  09/07/2014 0:00  416904.1667         3       2.50         3010
# 4598  10/07/2014 0:00  203400.0000         4       2.00         2090
# 4599  10/07/2014 0:00  220600.0000         3       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated             street       city  \
# 4595              0      1954          1979     501 N 143rd St    Seattle
# ...

# %% [markdown]
# ### List all the columns in the dataset

# %%
data.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %% [markdown]
# ### Find the number of rows and columns in the dataset

# %%
data.shape
# Out:
# (4600, 18)

# %% [markdown]
# ### Find the basic statistics of the dataset

# %%
data.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %% [markdown]
# ### Find the null value in the dataset

# %%
data.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %% [markdown]
# ### Find the mean price of house

# %%
data['price'].mean()
# Out:
# 551962.9884730439

# %% [markdown]
# ### Check the price, bedrooms, city and street data between row 100 and 110

# %%
data.loc[100:110, ['price', 'bedrooms', 'city', 'street']]
# Out:
#          price  bedrooms         city                street
# 100   736500.0         4       Renton     17132 SE 100th St
# 101   570000.0         3      Redmond     10204 168th Pl NE
# 102   787000.0         3     Bellevue      218 109th Ave SE
# 103   328000.0         4       Auburn    12621 SE 300th Way
# 104   435000.0         5      Seattle  14013 Ashworth Ave N
# 105   499000.0         4   Snoqualmie  34010 SE Sorenson St
# 106   501000.0         4     Bellevue     2506 166th Ave NE
# 107  1090000.0         4      Redmond     8814 218th Ave NE
# 108   400000.0         2      Seattle    4515 SW Trenton St
# 109   220000.0         4  Federal Way      4924 SW 314th Pl
# 110   657100.0         4      Seattle   4312 Woodlawn Ave N

# %% [markdown]
# ### Do the same thing as above using iloc for their positioning

# %%
data.iloc[100:111, [1,2,15,14]]
# Out:
#          price  bedrooms         city                street
# 100   736500.0         4       Renton     17132 SE 100th St
# 101   570000.0         3      Redmond     10204 168th Pl NE
# 102   787000.0         3     Bellevue      218 109th Ave SE
# 103   328000.0         4       Auburn    12621 SE 300th Way
# 104   435000.0         5      Seattle  14013 Ashworth Ave N
# 105   499000.0         4   Snoqualmie  34010 SE Sorenson St
# 106   501000.0         4     Bellevue     2506 166th Ave NE
# 107  1090000.0         4      Redmond     8814 218th Ave NE
# 108   400000.0         2      Seattle    4515 SW Trenton St
# 109   220000.0         4  Federal Way      4924 SW 314th Pl
# 110   657100.0         4      Seattle   4312 Woodlawn Ave N

# %% [markdown]
# ### Find the house data whose prices are more than 5Million, and print out their specific price, bedroom no, location and the house age (you will create a new column for the house age)

# %% [markdown]
# ###### creating the current age column and also the house age

# %%
data_sub['curr_date'] = pd.to_datetime('today').year
# Out:
# <ipython-input-80-322d35995589>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sub['curr_date'] = pd.to_datetime('today').year

# %%
data_sub['house_age']= data_sub['curr_date'] - data_sub['yr_built']
# Out:
# <ipython-input-82-5ff6789a1376>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sub['house_age']= data_sub['curr_date'] - data_sub['yr_built']

# %%
data_sub = data[data['price']>5000000]
data_sub
# Out:
#                  date       price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 2286  11/06/2014 0:00   7062500.0         5        4.5        10040     37325
# 4346  23/06/2014 0:00  12899000.0         3        2.5         2190     11394
# 4350  03/07/2014 0:00  26590000.0         3        2.0         1180      7793
#
#       floors  waterfront  view  condition  sqft_above  sqft_basement  \
# 2286     2.0           1     2          3        7680           2360
# 4346     1.0           0     0          3        1550            640
# 4350     1.0           0     0          4        1180              0
#
#       yr_built  yr_renovated             street      city  statezip country
# 2286      1940          2001   4442 95th Ave NE  Bellevue  WA 98004     USA
# 4346      1956          2001    5426 40th Ave W   Seattle  WA 98199     USA
# 4350      1992             0  12005 SE 219th Ct      Kent  WA 98031     USA

# %%
data_sub.loc[:,['price', 'bedrooms', 'city', 'street', 'yr_built', 'house_age']]
# Out:
#            price  bedrooms      city             street  yr_built  house_age
# 2286   7062500.0         5  Bellevue   4442 95th Ave NE      1940         81
# 4346  12899000.0         3   Seattle    5426 40th Ave W      1956         65
# 4350  26590000.0         3      Kent  12005 SE 219th Ct      1992         29

# %% [markdown]
# ### Select all the rows whose city is Kent, how many are they

# %%
data_kent = data[ data['city'] == "Kent"]
data_kent
# Out:
#                  date        price  bedrooms  bathrooms  sqft_living  \
# 2     02/05/2014 0:00  342000.0000         3       2.00         1930
# 15    02/05/2014 0:00  242500.0000         3       1.50         1200
# 63    02/05/2014 0:00  300000.0000         3       2.50         2540
# 176   06/05/2014 0:00  284000.0000         4       2.50         2000
# 244   07/05/2014 0:00  310000.0000         3       1.75         2070
# ...               ...          ...       ...        ...          ...
# 4512  19/06/2014 0:00  220083.3333         3       1.75         1150
# 4547  26/06/2014 0:00  264270.0000         3       2.50         1630
# 4560  30/06/2014 0:00  132250.0000         4       2.25         1830
# 4569  02/07/2014 0:00  268971.8750         4       2.50         1954
# 4594  09/07/2014 0:00  210614.2857         3       2.50         1610
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 2        11947     1.0           0     0          4        1930
# ...

# %%
data_kent.count()
# Out:
# date             185
# price            185
# bedrooms         185
# bathrooms        185
# sqft_living      185
# sqft_lot         185
# floors           185
# waterfront       185
# view             185
# condition        185
# sqft_above       185
# sqft_basement    185
# yr_built         185
# yr_renovated     185
# street           185
# city             185
# statezip         185
# country          185
# dtype: int64

# %% [markdown]
# ### Group the data by city and in alphabetical order, find the max price of house in each city

# %%
city_group= data.groupby(['city'])

# %%
price_by_max_city= data.groupby(['city'], sort= True)[['price']].max()
price_by_max_city
# Out:
#                           price
# city
# Algona                 262000.0
# Auburn                 900000.0
# Beaux Arts Village     745000.0
# Bellevue              7062500.0
# Black Diamond          650000.0
# Bothell                749995.0
# Burien                1035000.0
# Carnation             1680000.0
# Clyde Hill            3800000.0
# Covington             2199900.0
# Des Moines             950000.0
# Duvall                 955000.0
# Enumclaw               687000.0
# Fall City             1600000.0
# Federal Way            819000.0
# Inglewood-Finn Hill    425000.0
# Issaquah              2238888.0
# Kenmore               1120000.0
# Kent                 26590000.0
# Kirkland              3000000.0
# Lake Forest Park       790000.0
# Maple Valley           725000.0
# Medina                3710000.0
# Mercer Island         4668000.0
# Milton                 320000.0
# Newcastle             1200000.0
# Normandy Park         1309500.0
# North Bend             845000.0
# ...

# %% [markdown]
# ### From the data, print out the prices, bedroom number and cities with top 5 prices

# %%
data_sorted = data.sort_values( by = 'price')
data_sorted_maxprice = data_sorted.tail()

# %%
data_sorted_maxprice.loc[:,['price', 'bedrooms', 'city']]
# Out:
#            price  bedrooms           city
# 2761   4489000.0         4       Bellevue
# 2654   4668000.0         5  Mercer Island
# 2286   7062500.0         5       Bellevue
# 4346  12899000.0         3        Seattle
# 4350  26590000.0         3           Kent
